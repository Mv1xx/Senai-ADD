# %%
import pandas as pd

smartfactory = pd.read_csv("4 - SmartFactory_300_Registros.csv")
smartfactory
# Out:
#      ID_Registro Data_Leitura  Hora  Minuto        Equipamento      Setor  \
# 0              1   03-05-2025    19      21        Torno C N C  Montagem
# 1              2   2025-03-20    21      53  Prensa Hidraulica  Montagem
# 2              3   23/01/2025    14      53           TornoCNC  Montagem
# 3              4   2025-05-02     6      31        Torno C N C  Montagem
# 4              5   16-06-2025    15       2           TornoCNC      Usin.
# ..           ...          ...   ...     ...                ...        ...
# 295          296   17/05/2025    20      55  Esteira Principal      Usin.
# 296          297   2025-01-08    16      56          Soldadora      Usin.
# 297          298   31-05-2025    20      26        Injetora 02      Usin.
# 298          299   17-03-2025     9      30        Injetora 01  Montagem
# 299          300   08-04-2025    17      35          Soldadora  Montagem
#
#      Fabricante   Tipo_Sensor Codigo_Sensor  Valor_Leitura  Limite_Minimo  \
# ...

# %% [markdown]
# <h3>Unificando Valores</h3>

# %%
smartfactory['Equipamento'].unique()
# Out:
# <StringArray>
# [       'Torno C N C',  'Prensa Hidraulica',           'TornoCNC',
#   'Prensa Hidráulica',          'Torno CNC',          'Soldadora',
#  'Centro de Usinagem',      'Compressor 01',  'Esteira Principal',
#         'Injetora 02',        'Injetora 01',           'Caldeira',
#       'Compressor 02']
# Length: 13, dtype: str

# %%
smartfactory['Setor'].unique()
# Out:
# <StringArray>
# ['Montagem ', 'Usin.']
# Length: 2, dtype: str

# %%
smartfactory['Tipo_Sensor'].unique()
# Out:
# <StringArray>
# ['Vibracao', 'Temp.', 'Temperatura ']
# Length: 3, dtype: str

# %%
smartfactory['Alerta_Gerado'].unique()
# Out:
# <StringArray>
# ['Não', 'Sim']
# Length: 2, dtype: str
